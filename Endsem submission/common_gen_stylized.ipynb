# %%
# !pip install transformers datasets sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 53.6 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 44.9 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.4.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 27.1 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.7 MB/s eta 0:00:00
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.6 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.3/269.3 kB 23.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 23.6 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 16.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: tokenizers, sentencepiece, xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.13.4 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 sentencepiece-0.1.98 tokenizers-0.13.3 transformers-4.28.1 xxhash-3.2.0 yarl-1.9.1

# %%
# !python --version
# Out:
# Python 3.9.16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from transformers import AutoTokenizer, AdamWeightDecay, TFAutoModelForSeq2SeqLM
from transformers.keras_callbacks import KerasMetricCallback
from transformers.keras_callbacks import PushToHubCallback
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
import numpy as np
from datasets import load_metric
from nltk.translate.bleu_score import sentence_bleu
from datasets import load_dataset
# import evaluate
from transformers import GPT2Tokenizer, GPT2Model
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast
from transformers import AutoModelWithLMHead, AutoTokenizer
from datasets import Dataset
import pandas as pd
from sklearn.model_selection import train_test_split
import torch 
from tensorflow.keras.preprocessing.text import Tokenizer
import string
import pickle

# %%
df = pickle.load(open('/content/drive/MyDrive/Information Retrieval Project/FINAL SUBMISSION FILES/final_gpt_dataset_for_creative_captions.pkl', 'rb'))

# %%
df
# Out:
#                                        Original Caption  \
# 0     Beauty and the beast is this prince that's all...
# 1     A rare photograph of an actor signing autographs.
# 2     A model walks the runway for a fashion show du...
# 3     Rock artist is the first artist to win a posth...
# 4                     Fat mouse with a piece of cheese.
# ...                                                 ...
# 3692  the jersey and shoes worn by on his - yard pas...
# 3693
# 3694     preparation of person to the annual inspection
# 3695                         gold frame made in vector.
# 3696                 hippopotamus eat grass in the zoo.
#
#                                      Creative Caption 1  \
# 0                      "Falling for the fairytale 🌹 🥀
# 1                     "Capturing a moment in time 📸 🎬
# 2                "Walking on air in couture flair ✨ 👠
# 3                   "Remembering a musical genius 🎵 🤘
# 4           "Living my best life with some cheese 🧀 😋
# ...                                                 ...
# 3692  A moment in time forever captured in this icon...
# 3693      Scoring big goals, one kick at a time. ⚽ ️🏆
# 3694  Preparing to ace the annual inspection like a ...
# 3695  Elevate your art with our elegant gold frames....
# 3696  Hungry, hungry hippos enjoying some fresh gree...
#
#                                      Creative Caption 2  \
# 0                         "A tale as old as time 🕰 ️💕
# 1                "Inked memories for a lifetime 🖋 ️🎞 ️
# 2                     "Stealing the show in style 👑 🌟
# 3                              "Legends never die 🎸 🌟
# 4                                "Food coma goals 🐭 💤
# ...                                                 ...
# 3692  From the yard to the showcase, a true football...
# 3693  Kicking my way to victory, one game at a time....
# 3694  Getting ready to impress at the annual review....
# 3695   A touch of gold can make all the difference. 🌟
# 3696  A hippo's gotta eat! Chowin' down on some leaf...
#
#                                      Creative Caption 3
# 0               "Happily ever after with my beast 👸 🦁
# 1                         "A glimpse into history 🎥 🔮
# 2          "Strutting my stuff in the limelight 💃 🏻 ✨
# 3           "Living on through the power of music 🎶 🎤
# 4                                     "Say cheese 📸 🐁
# ...                                                 ...
# 3692  The shoes that ran the yard, now a symbol of g...
# 3693               When I kick, the world moves. ⚽ ️💪
# 3694    Sharpening skills for the annual checkup. 📝 🧐
# 3695        Frame your world in glittering gold. ✨ 🖼 ️
# 3696  Grazing in the zoo with my favorite hippo pals...
#
# [7305 rows x 4 columns]

# %%
# df = pd.read_csv('/content/drive/MyDrive/Information Retrieval Project/Instagram worthy captions dataset/final_data.csv')

# %%
df = df.dropna(axis = 0, how = 'any')

# %%
df
# Out:
#                                        Original Caption  \
# 0     Beauty and the beast is this prince that's all...
# 1     A rare photograph of an actor signing autographs.
# 2     A model walks the runway for a fashion show du...
# 3     Rock artist is the first artist to win a posth...
# 4                     Fat mouse with a piece of cheese.
# ...                                                 ...
# 3692  the jersey and shoes worn by on his - yard pas...
# 3693
# 3694     preparation of person to the annual inspection
# 3695                         gold frame made in vector.
# 3696                 hippopotamus eat grass in the zoo.
#
#                                      Creative Caption 1  \
# 0                      "Falling for the fairytale 🌹 🥀
# 1                     "Capturing a moment in time 📸 🎬
# 2                "Walking on air in couture flair ✨ 👠
# 3                   "Remembering a musical genius 🎵 🤘
# 4           "Living my best life with some cheese 🧀 😋
# ...                                                 ...
# 3692  A moment in time forever captured in this icon...
# 3693      Scoring big goals, one kick at a time. ⚽ ️🏆
# 3694  Preparing to ace the annual inspection like a ...
# 3695  Elevate your art with our elegant gold frames....
# 3696  Hungry, hungry hippos enjoying some fresh gree...
#
#                                      Creative Caption 2  \
# 0                         "A tale as old as time 🕰 ️💕
# 1                "Inked memories for a lifetime 🖋 ️🎞 ️
# 2                     "Stealing the show in style 👑 🌟
# 3                              "Legends never die 🎸 🌟
# 4                                "Food coma goals 🐭 💤
# ...                                                 ...
# 3692  From the yard to the showcase, a true football...
# 3693  Kicking my way to victory, one game at a time....
# 3694  Getting ready to impress at the annual review....
# 3695   A touch of gold can make all the difference. 🌟
# 3696  A hippo's gotta eat! Chowin' down on some leaf...
#
#                                      Creative Caption 3
# 0               "Happily ever after with my beast 👸 🦁
# 1                         "A glimpse into history 🎥 🔮
# 2          "Strutting my stuff in the limelight 💃 🏻 ✨
# 3           "Living on through the power of music 🎶 🎤
# 4                                     "Say cheese 📸 🐁
# ...                                                 ...
# 3692  The shoes that ran the yard, now a symbol of g...
# 3693               When I kick, the world moves. ⚽ ️💪
# 3694    Sharpening skills for the annual checkup. 📝 🧐
# 3695        Frame your world in glittering gold. ✨ 🖼 ️
# 3696  Grazing in the zoo with my favorite hippo pals...
#
# [7305 rows x 4 columns]

# %%
df.reset_index(drop = True, inplace = True)

# %%
train, test = train_test_split(df, test_size=0.1)

# %%
train, val = train_test_split(train, test_size = 0.1)

# %%
train1 = train.loc[:, ['Original Caption', 'Creative Caption 1']].reset_index(drop = True)
train2 = train.loc[:, ['Original Caption', 'Creative Caption 2']].reset_index(drop = True)
train3 = train.loc[:, ['Original Caption', 'Creative Caption 3']].reset_index(drop = True)

# %%
train1.rename(columns = {'Creative Caption 1': 'Creative Caption'}, inplace = True)
train2.rename(columns = {'Creative Caption 2': 'Creative Caption'}, inplace = True)
train3.rename(columns = {'Creative Caption 3': 'Creative Caption'}, inplace = True)

# %%
train = pd.concat([train1, train2, train3], ignore_index = True)

# %%
val1 = val.loc[:, ['Original Caption', 'Creative Caption 1']].reset_index(drop = True)
val2 = val.loc[:, ['Original Caption', 'Creative Caption 2']].reset_index(drop = True)
val3 = val.loc[:, ['Original Caption', 'Creative Caption 3']].reset_index(drop = True)

val1.rename(columns = {'Creative Caption 1': 'Creative Caption'}, inplace = True)
val2.rename(columns = {'Creative Caption 2': 'Creative Caption'}, inplace = True)
val3.rename(columns = {'Creative Caption 3': 'Creative Caption'}, inplace = True)

val = pd.concat([val1, val2, val3], ignore_index = True)

# %%
test1 = test.loc[:, ['Original Caption', 'Creative Caption 1']].reset_index(drop = True)
test2 = test.loc[:, ['Original Caption', 'Creative Caption 2']].reset_index(drop = True)
test3 = test.loc[:, ['Original Caption', 'Creative Caption 3']].reset_index(drop = True)

test1.rename(columns = {'Creative Caption 1': 'Creative Caption'}, inplace = True)
test2.rename(columns = {'Creative Caption 2': 'Creative Caption'}, inplace = True)
test3.rename(columns = {'Creative Caption 3': 'Creative Caption'}, inplace = True)

test = pd.concat([test1, test2, test3], ignore_index = True)

# %%
train = train.applymap(lambda x: '<SOS> ' + x + ' <EOS>' if type(x) == str else x)
val = val.applymap(lambda x: '<SOS> ' + x + ' <EOS>' if type(x) == str else x)
test = test.applymap(lambda x: '<SOS> ' + x + ' <EOS>' if type(x) == str else x)

# %%
train = Dataset.from_pandas(train.reset_index(drop = True))
val = Dataset.from_pandas(val.reset_index(drop = True))
test = Dataset.from_pandas(test.reset_index(drop = True))

# %%
len(train), len(val), len(test)
# Out:
# (17748, 1974, 2193)

# %%
max_len = 0
for pair in train:
  max_len = max(max_len, len(pair['Original Caption'].split()), len(pair['Creative Caption'].split()))

for pair in val:
  max_len = max(max_len, len(pair['Original Caption'].split()), len(pair['Creative Caption'].split()))

for pair in test:
  max_len = max(max_len, len(pair['Original Caption'].split()), len(pair['Creative Caption'].split()))

max_len
# Out:
# 47

# %%
self_tokenizer = Tokenizer(filters='', oov_token='<OOV>')
self_tokenizer.fit_on_texts(train['Original Caption'])
self_tokenizer.fit_on_texts(train['Creative Caption'])
self_tokenizer.fit_on_texts(val['Original Caption'])
self_tokenizer.fit_on_texts(val['Creative Caption'])
self_tokenizer.fit_on_texts(test['Original Caption'])
self_tokenizer.fit_on_texts(test['Creative Caption'])

# %%
checkpoint = 'mrm8488/t5-base-finetuned-common_gen'
tokenizer = AutoTokenizer.from_pretrained("mrm8488/t5-base-finetuned-common_gen")

# %%
new_tokens = set(self_tokenizer.word_index.keys()) - set(tokenizer.vocab.keys())

# %%
new_tokens_clean = set()
for token in new_tokens:
  new_tokens_clean.add(token.translate(str.maketrans('', '', string.punctuation)))

# %%
temp = set()
new_tokens = set()
for tokens in new_tokens_clean:
  if '<SOS>'  in tokens or '<EOS>' in tokens:
    continue
  if tokens.isalnum() == False:
    temp.add(tokens)
  else:
    new_tokens.add(tokens)

# %%
temp = list(temp)

for i in range(len(temp)):
  if len(temp[i]) == 0:
    continue
  temp[i] = temp[i][-1]

temp

# %%
new_tokens = []

for emoji in list(temp):
  new_tokens.append(emoji)

# %%
tokenizer.add_tokens(temp)
# Out:
# 959

# %%
special_tokens = ['<SOS>', '<EOS>', 'write creatively: ']
tokenizer.add_tokens(special_tokens, special_tokens=True)
# Out:
# 3

# %%
print("hello world")
# Out:
# hello world

# %%
prefix = "write creatively: "

def preprocess_function(examples):
  # print(examples)
  inputs = [prefix + example for example in examples['Original Caption']]
  targets = [example for example in examples['Creative Caption']]
  # print(inputs)
  # print(targets)
  model_inputs = tokenizer(inputs, max_length = max_len, truncation = True, padding = True, text_target = targets, return_tensors = 'pt')
  # print(type(model_inputs))
  return model_inputs

# %%
train = train.map(preprocess_function, batched = True)
val = val.map(preprocess_function, batched = True)
# Out:
# Map:   0%|          | 0/17748 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1974 [00:00<?, ? examples/s]

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

# %%
# metric = evaluate.load('sacrebleu')
# rouge_metric = load_metric('rouge')

# def postprocess_text(preds, labels):
#     preds = [pred.strip() for pred in preds]
#     labels = [[label.strip()] for label in labels]

#     return preds, labels


# def compute_metrics(eval_preds):
#     preds, labels = eval_preds
#     if isinstance(preds, tuple):
#         preds = preds[0]
#     decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

#     labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
#     decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

#     decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

#     result = metric.compute(predictions=decoded_preds, references=decoded_labels)
#     result = {"bleu": result["score"]}
#     prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
#     result["gen_len"] = np.mean(prediction_lens)
#     result = {k: round(v, 4) for k, v in result.items()}
#     return result

# %%
torch.cuda.empty_cache()

# %%
model = AutoModelWithLMHead.from_pretrained("mrm8488/t5-base-finetuned-common_gen").cuda()
model.resize_token_embeddings(len(tokenizer))
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/models/auto/modeling_auto.py:1322: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# Embedding(32103, 768)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="/content/drive/MyDrive/Information Retrieval Project/saved_models/common_gen_new",
    evaluation_strategy="epoch",
    learning_rate=2e-3,
    per_device_train_batch_size=64,
    per_device_eval_batch_size=64,
    weight_decay=0.01,
    num_train_epochs=1,
    predict_with_generate=True,
    fp16=True,
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train,
    eval_dataset = val,
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='278' max='278' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [278/278 02:31, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.821242</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=278, training_loss=1.0820580352124551, metrics={'train_runtime': 151.9177, 'train_samples_per_second': 116.826, 'train_steps_per_second': 1.83, 'total_flos': 992120855777280.0, 'train_loss': 1.0820580352124551, 'epoch': 1.0})

# %%
train
# Out:
# Dataset({
#     features: ['Original Caption', 'Creative Caption', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 17748
# })

# %%
trainer.save_model('/content/drive/MyDrive/Information Retrieval Project/saved_models/common_gen_new_model')

# %%
temp = prefix + test['Original Caption'][16]
# temp = prefix + 'vector illustration of a colorful shiny lamp for person with brown background'
temp = tokenizer(temp, max_length = max_len, truncation = True, padding = True, return_tensors = 'pt').input_ids.cuda()
temp = model.generate(temp)

# %%
temp
# Out:
# tensor([[    0, 32100,    96,   567,     9,  2693,    31,     7,  3337,    40,
#            232,    55,     3,     2,     3,     2,     3, 32101,     1]],
#        device='cuda:0')

# %%
tokenizer.batch_decode(temp)
# Out:
# ['<pad><SOS> "Nature\'s wonderland! <unk> <unk> <EOS></s>']

# %%
test['Original Caption'][16]
# Out:
# '<SOS> you can see the natural sand on the path to the beach from this lot. <EOS>'

# %%
test["Creative Caption"][4]
# Out:
# '<SOS> "Sweet summer vibes with my favorite fruit 🍉 ☀ ️  <EOS>'

# %%
def testing(examples):
  inputs = [prefix + example for example in examples['Original Caption']]
  model_inputs = tokenizer(inputs, max_length = max_len, truncation = True, padding = True, return_tensors = 'pt')
  return model_inputs

# %%
test_dataset = test.map(testing, batched = True)
# Out:
# Map:   0%|          | 0/879 [00:00<?, ? examples/s]

# %%
test_dataset
# Out:
# Dataset({
#     features: ['Original Caption', 'Creative Caption', 'input_ids', 'attention_mask'],
#     num_rows: 879
# })

# %%
model_output_ids = []
for sample in test:
  temp = prefix + sample['Original Caption']
  temp = tokenizer(temp, max_length = max_len, truncation = True, padding = True, return_tensors = 'pt').input_ids.cuda()
  temp = model.generate(temp)
  model_output_ids.append(temp)
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
model_outputs = []

for ids in model_output_ids:
  model_outputs.append(tokenizer.batch_decode(ids))

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
bleu_original = 0
bleu_insta = 0

for i in range(len(model_outputs)):
  # print(test[i]['Original Caption'], ' space ',model_outputs[i])
  bleu_original += sentence_bleu([test[i]['Original Caption']], model_outputs[i][0])
  bleu_insta += sentence_bleu([test[i]['Creative Caption']], model_outputs[i][0])

bleu_original /= len(model_outputs)
bleu_insta /= len(model_outputs)

# %%
bleu_insta, bleu_original
# Out:
# (0.27613493758097335, 0.3874061470404573)

# %%
import pickle

# %%
pickle.dump(train, open('/content/drive/MyDrive/Information Retrieval Project/common_gen_17k_files/train_set.pkl', 'wb'))

# %%
pickle.dump(val, open('/content/drive/MyDrive/Information Retrieval Project/common_gen_17k_files/val_set.pkl', 'wb'))

# %%
pickle.dump(val, open('/content/drive/MyDrive/Information Retrieval Project/common_gen_17k_files/test_set.pkl', 'wb'))

# %%
pickle.dump(model_outputs, open('/content/drive/MyDrive/Information Retrieval Project/common_gen_17k_files/model_outputs.pkl', 'wb'))

# %%
conceptual_captions = pickle.load(open('/content/drive/MyDrive/Information Retrieval Project/vit-gpt2/conceptual_results/data_with_generated_captions.pkl', 'rb'))

# %%
conceptual_captions
# Out:
#                                        Original Caption  \
# 1000  sparkling glittery gold uppercase or capital l...
# 1001                     actor arrives for the premiere
# 1002  i jumped out of a helicopter and you can see t...
# 1003  athlete prepares to score a touchdown as his t...
# 1004  baseball player shakes hands with baseball pla...
# ...                                                 ...
# 1995  a bit of the view from our table on new year '...
# 1996           actor wears a slim grey suit to awards .
# 1997                         a side street viewed not .
# 1998  map with long shadow and white outline on blue...
# 1999            terracotta painted relief from a temple
#
#                                                   Image  \
# 1000  https://thumb1.shutterstock.com/display_pic_wi...
# 1001  https://media.gettyimages.com/photos/kristen-b...
# 1002                     http://i.imgur.com/ynzWXIO.jpg
# 1003  http://photos.mycapture.com/THST/1561986/44629...
# 1004  https://billieweiss.files.wordpress.com/2014/0...
# ...                                                 ...
# 1995  https://media-cdn.tripadvisor.com/media/photo-...
# 1996  http://www.windsorstar.com/cms/binary/6493391....
# 1997  https://www.jefflindsay.com/gif/asia/shanghai_...
# 1998  https://thumb1.shutterstock.com/display_pic_wi...
# 1999  https://t4.thpservices.com/previewimage/gallag...
#
#                           Generated_descriptive_caption
# 1000          a white and black vase with a bird on it
# 1001  a woman in a red dress standing in front of a ...
# 1002        a person holding a surfboard in their hand
# 1003                                                  #
# 1004                                                  #
# ...                                                 ...
# 1995         a city with lots of buildings and a river
# 1996                                                  #
# 1997        a sign that says "don't drink in the city"
# 1998                                                  #
# 1999  a painting of a horse with a statue of a man o...
#
# [1000 rows x 3 columns]

# %%
con_cap = conceptual_captions[conceptual_captions['Generated_descriptive_caption'] != '#']

# %%
con_dataset = Dataset.from_pandas(con_cap)

# %%
con_output_ids = []

for sample in con_dataset:
  temp = prefix + sample['Generated_descriptive_caption']
  temp = tokenizer(temp, max_length = max_len, truncation = True, padding = True, return_tensors = 'pt').input_ids.cuda()
  temp = model.generate(temp)
  con_output_ids.append(temp)
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
con_outputs = []

for ids in con_output_ids:
  con_outputs.append(tokenizer.batch_decode(ids))

# %%
con_bleu_original = 0
con_bleu_desc = 0
for i in range(len(con_outputs)):
  # print(con_dataset[i]['Original Caption'], ' space ',model_outputs[i])
  con_bleu_original += sentence_bleu([con_dataset[i]['Original Caption']], con_outputs[i][0])
  con_bleu_desc += sentence_bleu([con_dataset[i]['Generated_descriptive_caption']], con_outputs[i][0])

con_bleu_original /= len(con_outputs)
con_bleu_desc /= len(con_outputs)
# Out:
# /usr/local/lib/python3.9/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.9/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.9/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
con_bleu_original, con_bleu_desc
# Out:
# (0.10281281645921732, 0.3433259959521282)

# %%
from PIL import Image
import requests
from io import BytesIO

# %%
for i in range(5):
  response = requests.get(con_dataset[i]['Image'])
  img = Image.open(BytesIO(response.content))
  img.show()
  print(con_outputs[i])
  print(con_dataset[i]['Original Caption'])
  print(con_dataset[i]['Generated_descriptive_caption'])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
pickle.dump(con_dataset, open('/content/drive/MyDrive/Information Retrieval Project/common_gen_7k_files/conceptual_dataset.pkl', 'wb'))
pickle.dump(con_outputs, open('/content/drive/MyDrive/Information Retrieval Project/common_gen_7k_files/desc_con_outputs.pkl', 'wb'))

# %%
emoji_dataset = pd.read_csv('/content/drive/MyDrive/Information Retrieval Project/Instagram worthy captions dataset/final_data_with_emojis.csv')

# %%
emoji_dataset
# Out:
#        Unnamed: 0                                                  0  1
# 0               0                       "Falling for the fairytale    🌹
# 1               1                       "Falling for the fairytale    🥀
# 2               2                          "A tale as old as time ️   🕰
# 3               3                          "A tale as old as time ️   💕
# 4               4                "Happily ever after with my beast    👸
# ...           ...                                                ... ..
# 31133       31133           Charting my course to new adventures. ️   🗺
# 31134       31134                    The world is your playground.    🌏
# 31135       31135  Captivated by the intricate details of ancient...  🏛
# 31136       31136             The beauty of art is in the details.    🎨
# 31137       31137  Uncovering the mysteries of the past through a...  🕵
#
# [31138 rows x 3 columns]
